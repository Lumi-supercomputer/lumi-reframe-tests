# %%
import pandas as pd
from IPython.display import display
from datetime import datetime

# %%
df = pd.read_csv('../../lumi-tds/gpu/lumi_gromacs_stmv.log', sep=',', header=0, index_col=['job_completion_time'], usecols=['name','system', 'partition','perf_var=perf_value perf_unit', 'job_completion_time'])

# %% [markdown]
# # LUMI Test and Development System (TDS)
# ***

# %%
display("Refreshed on:", datetime.now().strftime("%d/%m/%Y %H:%M:%S"))
# Out:
# 'Refreshed on:'
# '06/09/2024 13:51:21'

# %%
display(df)
# Out:
#                                                                         name  \
# job_completion_time
# 2024-09-04T15:15:11+03:00  lumi_gromacs_stmv module_ver=2024.3-cpeAMD-24....
# 2024-09-04T15:20:55+03:00  lumi_gromacs_stmv module_ver=2024.3-cpeAMD-24....
# 2024-09-04T15:30:49+03:00  lumi_gromacs_stmv module_ver=2024.3-cpeAMD-24....
# 2024-09-04T15:36:33+03:00  lumi_gromacs_stmv module_ver=2024.3-cpeAMD-24....
# 2024-09-04T17:10:02+03:00  lumi_gromacs_stmv module_ver=2024.1-cpeAMD-23....
# 2024-09-04T17:15:47+03:00  lumi_gromacs_stmv module_ver=2024.1-cpeAMD-23....
# 2024-09-04T17:45:07+03:00  lumi_gromacs_stmv module_ver=2024.1-cpeAMD-23....
# 2024-09-04T17:50:51+03:00  lumi_gromacs_stmv module_ver=2024.1-cpeAMD-23....
# 2024-09-05T10:35:33+03:00  lumi_gromacs_stmv module_ver=2024.3-cpeAMD-24....
# 2024-09-05T10:41:16+03:00  lumi_gromacs_stmv module_ver=2024.3-cpeAMD-24....
#
#                              system partition perf_var=perf_value perf_unit
# job_completion_time
# ...
